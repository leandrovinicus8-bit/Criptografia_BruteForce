# %% [markdown]
# <a href="https://colab.research.google.com/github/leandrovinicus8-bit/Criptografia_BruteForce/blob/main/Criptografia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# brute force - trablha a tentativa e erro via combinações
import itertools # biblioteca que faz combinações
import string # preciso saber como o pc pensa em um texto
import time
# computador falar para mim quanto tempo leva para descobrir uma senha

# passo 1 - alvo - o que o pc tenta adivinhar
def simulacao():
  senha_alvo = input('digite uma senha')
# passo 2 - armazenar tudo que ja foi feito
  # o pc usa uma tabela chamada ascii para salvar os caracteres
  caracteres = string.ascii_lowercase + string.digits
  #estamos juntando todas as letras e numeros
  print('tentando descobrir sua senha!')

  tempo_inicio = time.time()
  # time.time() registra o momento que o sistema iniciou
  tentativas = 0
  encontrado = False

# passo 3 - tentar descobrir algo
  for comprimento in range(1, len(senha_alvo) + 1):
    if encontrado: # if nome_encontrado ----- if var = True
      break

# passo 4 - combinado
    for combinacao in itertools.product(caracteres, repeat=comprimento):
      tentativas += 1
      palpite = "---".join(combinacao)

# passo 5 - feedback - mostrar o que ta fazendo
      if tentativas % 100000 == 0:
        print(f'tentativa de número {tentativas} ')
        print(f'testando o palpite {palpite}')

      if palpite == senha_alvo:
        tempo_fim = time.time()
        duracao = tempo_fim - tempo_inicio
        encontrado = True
        print(duracao)
# passo 6 - finalizar tudo
simulacao()
# Out:
# digite uma senhaluan
# tentando descobrir sua senha!
# tentativa de número 100000
# testando o palpite b---e---e---1
# tentativa de número 200000
# testando o palpite d---j---k---t
# tentativa de número 300000
# testando o palpite f---o---q---l
# tentativa de número 400000
# testando o palpite h---t---w---d
# tentativa de número 500000
# testando o palpite j---y---1---5
# tentativa de número 600000
# testando o palpite l---3---7---x
# tentativa de número 700000
# testando o palpite n---9---d---p
# tentativa de número 800000
# testando o palpite q---e---j---h
# tentativa de número 900000
# testando o palpite s---j---o---9
# tentativa de número 1000000
# testando o palpite u---o---u---1
# tentativa de número 1100000
# testando o palpite w---t---0---t
# tentativa de número 1200000
# testando o palpite y---y---6---l
# tentativa de número 1300000
# testando o palpite 0---4---c---d
# tentativa de número 1400000
# testando o palpite 2---9---h---5
# tentativa de número 1500000
# testando o palpite 5---e---n---x
# tentativa de número 1600000
# testando o palpite 7---j---t---p
# tentativa de número 1700000
# testando o palpite 9---o---z---h
